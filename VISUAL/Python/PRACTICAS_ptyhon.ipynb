# %% [markdown]
# ## Aprendiendo Python

# %% [markdown]
# #### Los ejercicios estan sacados de https://aprendeconalf.es/docencia/python/

# %% [markdown]
# #### Tipos de datos simples

# %% [markdown]
# ###### 2.Escribir un programa que almacene la cadena ¡Hola Mundo! en una variable y luego muestre por pantalla el contenido de la variable.

# %%
txt = "¡Hola Mundo!"
print(txt)
# Out:
# ¡Hola Mundo!

# %% [markdown]
# ###### 3.Escribir un programa que pregunte el nombre del usuario en la consola y después de que el usuario lo introduzca muestre por pantalla la cadena ¡Hola <nombre>!, donde <nombre> es el nombre que el usuario haya introducido.

# %%
name = input("Introduzca su nombre: ")
print("Hola "+name)
# Out:
# Hola  Jose Carlos

# %% [markdown]
# ###### 4.Escribir un programa que muestre por pantalla el resultado de la siguiente operación aritmética

# %% [markdown]
# $$\left(\frac{3+2}{2 \cdot 5}\right)^2$$

# %%
calc = ((3+2)/2*5)**2
print (calc)
# Out:
# 156.25

# %% [markdown]
# ###### 5.Escribir un programa que pregunte al usuario por el número de horas trabajadas y el coste por hora. Después debe mostrar por pantalla la paga que le corresponde.

# %%
horas = float (input(" Introduce las horas trabajadas: "))
coste = float (input ( "Introduce el coste de la hora: "))
paga = horas * coste 
print("Paga total: "+ str(paga) + "euros.")

# %% [markdown]
# ###### 6. Escribir un programa que lea un entero positivo,,introducido por el usuario y después muestre en pantalla la suma de todos los enteros desde 1 hasta.La suma de los  primeros enteros positivos puede ser calculada de la siguiente forma

# %%
n = int(input("Introduce un numero entero: "))
suma = n * (n+1) /2
print ("La suma de los primeros numeros enteros desde 1 hasta " + str(n) + "  es: " + str(suma))
# Out:
# La suma de los primeros numeros enteros desde 1 hasta 5  es: 15.0

# %% [markdown]
# ###### 7.Escribir un programa que pida al usuario su peso (en kg) y estatura (en metros), calcule el índice de masa corporal y lo almacene en una variable, y muestre por pantalla la frase Tu índice de masa corporal es <imc> donde <imc> es el índice de masa corporal calculado redondeado con dos decimales.

# %%
peso = float(input ("Introduce tu peso: "))
estatura = float(input ("Introduce tu altura: "))
imc = peso / estatura**2
print ( " Tu IMC es: "+ str(imc))
# Out:
#  Tu IMC es: 0.0016326530612244899

# %% [markdown]
# Ejercicio 8
# Escribir un programa que pida al usuario dos números enteros y muestre por pantalla la <n> entre <m> da un cociente <c> y un resto <r> donde <n> y <m> son los números introducidos por el usuario, y <c> y <r> son el cociente y el resto de la división entera respectivamente.

# %%
n=10
m=4
c=n/m
r=n%m
print( str (n) + " entre "+ str(m) + " da un cociente de " + str(c) + " y un resto de " + str(r))
# Out:
# 10 entre 4 da un cociente de 2.5 y un resto de 2

# %% [markdown]
# Ejercicio 9
# Escribir un programa que pregunte al usuario una cantidad a invertir, el interés anual y el número de años, y muestre por pantalla el capital obtenido en la inversión.

# %%
cinvertir= float(input ( "Introduce la cantidad a invertir: "))
intanual= float (input ( "Introduce el interes anual: "))
nyears= (int (input ( "Introduce el numero de años: ")))

final = intanual ** nyears *cinvertir
print ("El dinero final es: " + str(final))
# Out:
# El dinero final es: 805.2550000000002

# %% [markdown]
# Ejercicio 10
# Una juguetería tiene mucho éxito en dos de sus productos: payasos y muñecas. Suele hacer venta por correo y la empresa de logística les cobra por peso de cada paquete así que deben calcular el peso de los payasos y muñecas que saldrán en cada paquete a demanda. Cada payaso pesa 112 g y cada muñeca 75 g. Escribir un programa que lea el número de payasos y muñecas vendidos en el último pedido y calcule el peso total del paquete que será enviado.

# %%
payasos= 112
muñeca= 75

cantidadP= int (input ("Introduce la cantidad de payasos: "))
cantidadM= int(input ("Introduce la cantidad de muñecas: "))

total=( cantidadP*payasos)+ (cantidadM*muñeca)

print ("Aqui tienes el peso del paquete: " + str(total))
# Out:
# Aqui tienes el peso del paquete: 1870
